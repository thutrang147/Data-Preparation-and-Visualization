# %%
# pip install ucimlrepo
# Out:
# DEPRECATION: Loading egg at /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/PyEyeTrack-1.0.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
online_retail = fetch_ucirepo(id=352) 
  
# data (as pandas dataframes) 
X = online_retail.data.features 
y = online_retail.data.targets 
  
# metadata 
print(online_retail.metadata) 
  
# variable information 
print(online_retail.variables)
# Out:
# {'uci_id': 352, 'name': 'Online Retail', 'repository_url': 'https://archive.ics.uci.edu/dataset/352/online+retail', 'data_url': 'https://archive.ics.uci.edu/static/public/352/data.csv', 'abstract': 'This is a transactional data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.', 'area': 'Business', 'tasks': ['Classification', 'Clustering'], 'characteristics': ['Multivariate', 'Sequential', 'Time-Series'], 'num_instances': 541909, 'num_features': 6, 'feature_types': ['Integer', 'Real'], 'demographics': [], 'target_col': None, 'index_col': ['InvoiceNo', 'StockCode'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2015, 'last_updated': 'Mon Oct 21 2024', 'dataset_doi': '10.24432/C5BW33', 'creators': ['Daqing Chen'], 'intro_paper': {'ID': 361, 'type': 'NATIVE', 'title': 'Data mining for the online retail industry: A case study of RFM model-based customer segmen
# ...

# %%
X
# Out:
#                                 Description  Quantity      InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6   12/1/2010 8:26
# 1                       WHITE METAL LANTERN         6   12/1/2010 8:26
# 2            CREAM CUPID HEARTS COAT HANGER         8   12/1/2010 8:26
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6   12/1/2010 8:26
# 4            RED WOOLLY HOTTIE WHITE HEART.         6   12/1/2010 8:26
# ...                                     ...       ...              ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12  12/9/2011 12:50
# 541905         CHILDREN'S APRON DOLLY GIRL          6  12/9/2011 12:50
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4  12/9/2011 12:50
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4  12/9/2011 12:50
# 541908        BAKING SET 9 PIECE RETROSPOT          3  12/9/2011 12:50
#
#         UnitPrice  CustomerID         Country
# 0            2.55     17850.0  United Kingdom
# ...

# %%
y

# %%
X.dtypes
# Out:
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
import pandas as pd

# %%
online_retail2 = pd.read_excel("/Users/thutrang/Desktop/Code/NEU/DataPrepVisualize/Data/OnlineRetail2.xlsx")
online_retail2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
import numpy as np

# %%
data = {'Name': ['John', 'Anna', 'Peter', 'Linda', 'James'],
        'Age': [28, 22, np.nan, 32, 25],
        'City': ['New York', 'Paris', 'Berlin', np.nan, 'London'],
        'Salary': [70000, np.nan, 60000, 85000, np.nan]}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name   Age      City   Salary
# 0   John  28.0  New York  70000.0
# 1   Anna  22.0     Paris      NaN
# 2  Peter   NaN    Berlin  60000.0
# 3  Linda  32.0       NaN  85000.0
# 4  James  25.0    London      NaN

# %%
df.isnull()
# Out:
#     Name    Age   City  Salary
# 0  False  False  False   False
# 1  False  False  False    True
# 2  False   True  False   False
# 3  False  False   True   False
# 4  False  False  False    True

# %%
df['Salary'].fillna(value=df['Salary'].mean(), inplace=False)
# Out:
# 0    70000.000000
# 1    71666.666667
# 2    60000.000000
# 3    85000.000000
# 4    71666.666667
# Name: Salary, dtype: float64

# %%
df
# Out:
#     Name   Age      City        Salary
# 0   John  28.0  New York  70000.000000
# 1   Anna  22.0     Paris  71666.666667
# 2  Peter   NaN    Berlin  60000.000000
# 3  Linda  32.0       NaN  85000.000000
# 4  James  25.0    London  71666.666667

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                    columns=['letter', 'number'])
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                    columns=['letter', 'number', 'animal'])
df2
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1, df2], axis=0, join='outer')
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1, df2], axis=0, join='inner')
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
pd.concat([df1, df2], axis=1, join='outer')
# Out:
#   letter  number letter  number animal
# 0      a       1      c       3    cat
# 1      b       2      d       4    dog

# %%
pd.concat([df1, df2], axis=1, join='inner', ignore_index=True)
# Out:
#    0  1  2  3    4
# 0  a  1  c  3  cat
# 1  b  2  d  4  dog

# %%
pop = pd.read_csv("https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv")
pop.head()
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %%
areas = pd.read_csv("/Users/thutrang/Desktop/Code/NEU/DataPrepVisualize/Data/state-areas.csv")
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
abbrevs = pd.read_csv("https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv")
abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
df10 = areas.merge(abbrevs)
df10.head()
# Out:
#         state  area (sq. mi) abbreviation
# 0     Alabama          52423           AL
# 1      Alaska         656425           AK
# 2     Arizona         114006           AZ
# 3    Arkansas          53182           AR
# 4  California         163707           CA

# %%
final_df = pd.merge(df10, pop, how='inner', left_on='abbreviation', right_on='state/region')

# %%
final_df.head()
# Out:
#      state  area (sq. mi) abbreviation state/region     ages  year  population
# 0  Alabama          52423           AL           AL  under18  2012   1117489.0
# 1  Alabama          52423           AL           AL    total  2012   4817528.0
# 2  Alabama          52423           AL           AL  under18  2010   1130966.0
# 3  Alabama          52423           AL           AL    total  2010   4785570.0
# 4  Alabama          52423           AL           AL  under18  2011   1125763.0

# %%
df_2010 = final_df[final_df['year'] == 2010]

# %%
df_2010
# Out:
#                      state  area (sq. mi) abbreviation state/region     ages  \
# 2                  Alabama          52423           AL           AL  under18
# 3                  Alabama          52423           AL           AL    total
# 90                  Alaska         656425           AK           AK  under18
# 91                  Alaska         656425           AK           AK    total
# 100                Arizona         114006           AZ           AZ  under18
# ...                    ...            ...          ...          ...      ...
# 2347             Wisconsin          65503           WI           WI  under18
# 2356               Wyoming          97818           WY           WY  under18
# 2357               Wyoming          97818           WY           WY    total
# 2404  District of Columbia             68           DC           DC  under18
# 2405  District of Columbia             68           DC           DC    total
#
#       year  population
# ...

# %%
df_2010['density'] = df_2010['population'] / df_2010['area (sq. mi)']
# Out:
# /var/folders/bg/hsvxykxj7yx0jz1nrhc3k6z40000gn/T/ipykernel_2985/3010814147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2010['density'] = df_2010['population'] / df_2010['area (sq. mi)']

# %%
df_2010['rank'] = df_2010['density'].rank(ascending=False, method='dense')
# Out:
# /var/folders/bg/hsvxykxj7yx0jz1nrhc3k6z40000gn/T/ipykernel_2985/94835282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2010['rank'] = df_2010['density'].rank(ascending=False, method='dense')

# %%
df_2010
# Out:
#                      state  area (sq. mi) abbreviation state/region     ages  \
# 2                  Alabama          52423           AL           AL  under18
# 3                  Alabama          52423           AL           AL    total
# 90                  Alaska         656425           AK           AK  under18
# 91                  Alaska         656425           AK           AK    total
# 100                Arizona         114006           AZ           AZ  under18
# ...                    ...            ...          ...          ...      ...
# 2347             Wisconsin          65503           WI           WI  under18
# 2356               Wyoming          97818           WY           WY  under18
# 2357               Wyoming          97818           WY           WY    total
# 2404  District of Columbia             68           DC           DC  under18
# 2405  District of Columbia             68           DC           DC    total
#
#       year  population   rank      density
# ...

# %%
df_2010.drop(columns=['abbreviation', 'ages'])
# Out:
#                      state  area (sq. mi) state/region  year  population  \
# 2                  Alabama          52423           AL  2010   1130966.0
# 3                  Alabama          52423           AL  2010   4785570.0
# 90                  Alaska         656425           AK  2010    187902.0
# 91                  Alaska         656425           AK  2010    713868.0
# 100                Arizona         114006           AZ  2010   1628563.0
# ...                    ...            ...          ...   ...         ...
# 2347             Wisconsin          65503           WI  2010   1336094.0
# 2356               Wyoming          97818           WY  2010    135351.0
# 2357               Wyoming          97818           WY  2010    564222.0
# 2404  District of Columbia             68           DC  2010    101309.0
# 2405  District of Columbia             68           DC  2010    605125.0
#
#        rank      density
# 2      71.0    21.573851
# 3      33.0    91.287603
# ...

# %%
planets = pd.read_csv("/Users/thutrang/Desktop/Code/NEU/DataPrepVisualize/Data/planets.csv")

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
planets['number'].sum()
# Out:
# 1848

# %%
planets['orbital_period'].mean()
# Out:
# 2002.9175960947582

# %%
planets['method'].nunique()
# Out:
# 10

# %%
planets['mass'].max()
# Out:
# 25.0

# %%
planets['distance'].min()
# Out:
# 1.35
