# %%
import pandas as pd

# %%
data = pd.Series(['peter', 'Paul', None, 'MARY', 'gUIDO'])
# This would fail with a standard loop
# [s.capitalize() for s in data] # -> Raises an error because of None
# The correct way with Pandas
print(data.str.capitalize())
# Out:
# 0    Peter
# 1     Paul
# 2     None
# 3     Mary
# 4    Guido
# dtype: object

# %%
data.str.upper()
# Out:
# 0    PETER
# 1     PAUL
# 2     None
# 3     MARY
# 4    GUIDO
# dtype: object

# %%
data.str.split('a')
# Out:
# 0    [peter]
# 1    [P, ul]
# 2       None
# 3     [MARY]
# 4    [gUIDO]
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = pd.Series([' house ', 'kitchen', 'BATHROOM '])

# Case normalization
print("Upper case:\n", s.str.upper())

# Stripping whitespace
print("\nStripped:\n", s.str.strip())

# Replacing strings
print("\nReplaced:\n", s.str.replace(' ', '_'))
# Out:
# Upper case:
#  0       HOUSE
# 1      KITCHEN
# 2    BATHROOM
# dtype: object
#
# Stripped:
#  0       house
# 1     kitchen
# 2    BATHROOM
# dtype: object
#
# Replaced:
#  0      _house_
# 1      kitchen
# 2    BATHROOM_
# dtype: object

# %%
df_lab1 = pd.DataFrame({
'full_name': [' John Smith ', 'Jane Doe', ' peter jones '],
'location': ['123 Main St, New York, USA', '456 Oak Ave, London, UK', '789 Pine Ln, New York, USA']})

# %%
df_lab1
# Out:
#        full_name                    location
# 0    John Smith   123 Main St, New York, USA
# 1       Jane Doe     456 Oak Ave, London, UK
# 2   peter jones   789 Pine Ln, New York, USA

# %%
df_lab1['cleaned_name'] = df_lab1['full_name'].str.strip().str.title()

# %%
df_lab1
# Out:
#        full_name                    location cleaned_name
# 0    John Smith   123 Main St, New York, USA   John Smith
# 1       Jane Doe     456 Oak Ave, London, UK     Jane Doe
# 2   peter jones   789 Pine Ln, New York, USA  Peter Jones

# %%
df_lab1['ny_customers'] = df_lab1['location'].str.contains('New York')
df_lab1
# Out:
#        full_name                    location cleaned_name  ny_customers
# 0    John Smith   123 Main St, New York, USA   John Smith          True
# 1       Jane Doe     456 Oak Ave, London, UK     Jane Doe         False
# 2   peter jones   789 Pine Ln, New York, USA  Peter Jones          True

# %%
df_lab1[['street', 'city', 'country']] = df_lab1['location'].str.split(',', expand=True)
df_lab1
# Out:
#        full_name                    location cleaned_name  ny_customers  \
# 0    John Smith   123 Main St, New York, USA   John Smith          True
# 1       Jane Doe     456 Oak Ave, London, UK     Jane Doe         False
# 2   peter jones   789 Pine Ln, New York, USA  Peter Jones          True
#
#         street       city country
# 0  123 Main St   New York     USA
# 1  456 Oak Ave     London      UK
# 2  789 Pine Ln   New York     USA

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_comments = pd.DataFrame({
    'comments': [
        'REF-1234: Great product!',
        'Complaint: The item (REF-5678) was broken.',
        'REF-9101, love it! #awesome #greatbuy',
        'This is not a valid comment',
        'complaint: another issue with REF-1122']})

# %%
df_comments
# Out:
#                                      comments
# 0                    REF-1234: Great product!
# 1  Complaint: The item (REF-5678) was broken.
# 2       REF-9101, love it! #awesome #greatbuy
# 3                 This is not a valid comment
# 4      complaint: another issue with REF-1122

# %%
is_valid = df_comments['comments'].str.match(r'^(REF|Complaint)', case=False)
is_valid
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: comments, dtype: bool

# %%
df_sales = pd.DataFrame({
'date': ['2023-01-29',
'2023-01-30',
'2023-02-01',
'2023-02-02',
'2023-02-03'],
'sales': [250, 275, 310, 290, 350]})

# %%
df_sales
# Out:
#          date  sales
# 0  2023-01-29    250
# 1  2023-01-30    275
# 2  2023-02-01    310
# 3  2023-02-02    290
# 4  2023-02-03    350

# %%
pd.to_datetime(df_sales['date'])
# Out:
# 0   2023-01-29
# 1   2023-01-30
# 2   2023-02-01
# 3   2023-02-02
# 4   2023-02-03
# Name: date, dtype: datetime64[ns]

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/thutrang/Desktop/Code/NEU/DataPrepVisualize/Data/OnlineRetail.csv")
df.head()
# Out:
#   InvoiceNo StockCode                Description  Quantity  \
# 0    539993     22386    JUMBO BAG PINK POLKADOT        10
# 1    539993     21499         BLUE POLKADOT WRAP        25
# 2    539993     21498        RED RETROSPOT WRAP         25
# 3    539993     22379   RECYCLING BAG RETROSPOT          5
# 4    539993     20718  RED RETROSPOT SHOPPER BAG        10
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2011-01-04 10:00:00       1.95     13313.0  United Kingdom
# 1  2011-01-04 10:00:00       0.42     13313.0  United Kingdom
# 2  2011-01-04 10:00:00       0.42     13313.0  United Kingdom
# 3  2011-01-04 10:00:00       2.10     13313.0  United Kingdom
# 4  2011-01-04 10:00:00       1.25     13313.0  United Kingdom
